# %%
li=[]
list1=list('AYUSH')
print(list1)
# Out:
# ['A', 'Y', 'U', 'S', 'H']

# %%
a='RAM','SITA'
print(type(a))
# Out:
# <class 'tuple'>

# %%
t=tuple()
print(t)
# Out:
# ()

# %%
tup=('I','P')
print(tup)
# Out:
# ('I', 'P')

# %%
s={'a','b','c'}
s1={ }
s2=set()
print(s,s1,s2)
# Out:
# {'b', 'c', 'a'} {} set()

# %%
d1=dict()
d2={}
print(d1,d2)
# Out:
# {} {}
