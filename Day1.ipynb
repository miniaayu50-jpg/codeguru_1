# %%
#string
name_of_student = 'Ayush'
print(type(name_of_student))
name_of_student.upper()
# Out:
# <class 'str'>
# 'AYUSH'

# %%
number = 12
floarts= 12.45
complex_num = 34+8j
print(type(complex_num))
bool1=True
bool2=False
print(type(bool2),type(bool1))
# Out:
# <class 'complex'>
# <class 'bool'> <class 'bool'>

# %%
user_input = input('enter the number')
print(type(user_input))
#convert user input into number
num = int(user_input)
print(num,type(num))
# Out:
# enter the number 23
# <class 'str'>
# 23 <class 'int'>

# %%
user_input = input('enter the number')
print(type(user_input))
#convert user input into number
num = float(user_input)
print(num,type(num))
# Out:
# enter the number 34.03
# <class 'str'>
# 34.03 <class 'float'>

# %%
user_input = input('enter the number')
print(type(user_input))
#convert user input into number
num = int(user_input)
print(num,type(num))
# Out:
# enter the number 23
# <class 'str'>
# 23 <class 'int'>

# %%
a = bool(0)
print(a)
# Out:
# False

# %%
a = 23
b = 7

c = complex(a, b)
print(c)
# Out:
# (23+7j)

# %%
print(f"{a}+{b}j")
# Out:
# 23+7j

# %%
a = bool(0)
print(a)
# Out:
# False
