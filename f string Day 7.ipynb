# %%
name = 'Ayush Panchal'
template = f'I am {name}'
print(template)
# Out:
# I am Ayush Panchal

# %%
name = 'Ayush Panchal'
template = f'I am {name.upper()}'
print(template)
# Out:
# I am AYUSH PANCHAL

# %%
num1 = 100
num2 = 200
temp = f'addition of number 1 {num1} and number 2 {num2} is {num1 + num2}'
print(temp)
# Out:
# addition of number 1 100 and number 2200 is 300

# %%
name1 = 'ayush'
name2 = 'ankit'
name3 = 'golu'
age1 = 25
age2 = 16
age3 = 22
temp = f'Name : {name1:>12} Age : {age1:>2}'
print(temp)
temp = f'Name : {name2:>12} Age : {age2:>2}'
print(temp)
temp = f'Name : {name3:>12} Age : {age3:>2}'
print(temp)
# Out:
# Name :        ayush Age : 25
# Name :        ankit Age : 16
# Name :         golu Age : 22

# %%
name1 = 'ayush'
name2 = 'ankit'
name3 = 'golu'
age1 = 25
age2 = 16
age3 = 22
temp = f'Name : {name1:>12} Age : {age1:>2}'
print(temp)
temp = f'Name : {name2:<12} Age : {age2:>2}'
print(temp)
temp = f'Name : {name3:^12} Age : {age3:>2}'
print(temp)
# Out:
# Name :        ayush Age : 25
# Name : ankit        Age : 16
# Name :     golu     Age : 22

# %%
item_name = 'Pizza'
qty = 10
price = 100.995
temp = f' This { item_name} @Rate = {price:.2f} Total Coat is {(qty*price):.1f}'
print(temp)
# Out:
#  This Pizza @Rate = 101.00 Total Coat is 1010.0

# %%
item_name = 'Pizza'
qty = 10
price = 100.99
temp = f' This { item_name} @Rate = {price:.2f} Total Coat is {(qty*price):.1f}'
print(temp)
# Out:
#  This Pizza @Rate = 100.99 Total Coat is 1009.9

# %%
student_name = 'Dilip Sahu'
std = 'XII'
s1 = 'English'
s2 = 'Hindi'
s3 = 'Mathematics'
s1mm = 100
s2mm = 50
s3mm = 70
s1om = 80
s2om = 9
s3om = 48
totalom = s1om+s2om+s3om
totalmm = s1mm+s2mm+s3mm
print(f'Name of Student : {student_name.upper():<20} Class :{std}')
print("-"*50)
heads = f"{'Subject':<12}|{'MM':^3}|{'OM':>3}|"
line1 = f"{s1:<12}|{s1mm:^3}|{s1om:>3}|"
line2 = f"{s2:<12}|{s2mm:^3}|{s2om:>3}|"
line3 = f"{s3:<12}|{s3mm:^3}|{s3om:>3}|"

print(heads)
print("-"*21)
print(line1)
print("-"*21)
print(line2)
print("-"*21)
print(line3)
print("-"*21)
print(f'Total :{totalom:>13}|')
print("-"*50)
# Out:
# Name of Student : DILIP SAHU           Class :XII
# --------------------------------------------------
# Subject     |MM | OM|
# ---------------------
# English     |100| 80|
# ---------------------
# Hindi       |50 |  9|
# ---------------------
# Mathematics |70 | 48|
# ---------------------
# Total :          137|
# --------------------------------------------------

# %%
student_name = 'AYUSH PANCHAL'
std = 'XII'
s1 = 'English'
s2 = 'Hindi'
s3 = 'Mathematics'
s4 = 'Physics'
s5 = 'Chemistry'
s1mm = 100
s2mm = 100
s3mm = 100
s4mm = 70
s5mm = 70
s1om = 66
s2om = 77
s3om = 83
s4om = 79
s5om = 79
pp = 30
pc = 30
totalom = s1om+s2om+s3om+s4om+s5om
totalmm = s1mm+s2mm+s3mm+s4mm+s5mm
print(f'Name of Student : {student_name.upper():<20} Class :{std:<5} Roll no.:{21535472:<10} School No.{532275:<5}')
print("-"*100)
heads = f"{'Subject':<35}|{'MM':^15}|{'pp':^15}|{'OM':^15}|"
line1 = f"{s1:<35}|{s1mm:^15}|{ 0:^15}|{s1om:^15}|"
line2 = f"{s2:<35}|{s2mm:^15}|{ 0:^15}|{s2om:^15}|"
line3 = f"{s3:<35}|{s3mm:^15}|{ 0:^15}|{s3om:^15}|"

line4 = f"{s4:<35}|{s4mm:^16}|{pp:^14}|{s4om:^14}|"
line5 = f"{s5:<35}|{s5mm:^16}|{pp:^14}|{s5om:^14}|"

print(heads)
print("-"*100)
print(line1)
print("-"*100)
print(line2)
print("-"*100)
print(line3)
print("-"*100)
print(line4)
print("-"*100)
print(line5)
print("-"*100)
print(f'Total :{totalmm:>38}{totalom:>31}|')
print("-"*100)
print(f'Gread : A')
print(f'Pass')
# Out:
# Name of Student : AYUSH PANCHAL        Class :XII   Roll no.:21535472   School No.532275
# ----------------------------------------------------------------------------------------------------
# Subject                            |      MM       |      pp       |      OM       |
# ----------------------------------------------------------------------------------------------------
# English                            |      100      |       0       |      66       |
# ----------------------------------------------------------------------------------------------------
# Hindi                              |      100      |       0       |      77       |
# ----------------------------------------------------------------------------------------------------
# Mathematics                        |      100      |       0       |      83       |
# ----------------------------------------------------------------------------------------------------
# ...
