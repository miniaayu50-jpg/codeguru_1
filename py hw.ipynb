# %%
Sub1  = input('Enter subject name english')
Sub2  = input('Enter subject name hindi')
Sub3  = input('Enter subject name physics')
Sub4  = input('Enter subject name chemistry')
Sub5  = input('Enter subject name maths')
if (Sub1=='eng'):
    print('English')
else:
    print('enter valid subject')
if (Sub2=='hin'):
    print('Hindi')
else:
    print('enter valid subject')
if (Sub3=='phy'):
    print('Physics')
else:
    print('enter valid subject')
if (Sub4=='che'):
    print('Chemistry')
else:
    print('enter valid subject')
if (Sub5=='mat'):
    print('Maths')
else:
    print('enter valid subject')
sub1_marks = int(input("Enter marks obtained in english"))
if sub1_marks > 0 and sub1_marks <= 100:
    print('You obtained', sub1_marks, 'marks in English')
else:
    print('enter valid marks')
sub2_marks = int(input("Enter marks obtained in hindi"))
if sub2_marks > 0 and sub2_marks <= 100:
    print('You obtained', sub2_marks, 'marks in Hindi')
else:
    print('enter valid marks')
sub3_marks = int(input("Enter marks obtained in physics"))
if sub3_marks > 0 and sub3_marks <= 100:
    print('You obtained', sub3_marks, 'marks in Physics')
else:
    print('enter valid marks')
sub4_marks = int(input("Enter marks obtained in chemistry"))
if sub4_marks > 0 and sub4_marks <= 100:
    print('You obtained', sub4_marks, 'marks in Chemistry')
else:
    print('enter valid marks')
sub5_marks = int(input("Enter marks obtained in maths"))
if sub5_marks > 0 and sub5_marks <= 100:
    print('You obtained', sub5_marks, 'marks in Maths')
else:
    print('enter valid marks')



if sub1_marks >= 33 and sub2_marks >= 33 and sub3_marks >= 33 and sub4_marks >= 33 and sub5_marks >= 33:
    print('You are pass')
else:
    print('You are fail')
if sub1_marks >= 33:
    print('You are pass in english')
else:
    print('supplyment in english')
if sub2_marks >= 33:
    print('You are pass in hindi')
else:
    print('supplyment in hindi')
if sub3_marks >= 33:
    print('You are pass in physics')
else:
    print('supplyment in physics')
if sub4_marks >= 33:
    print('You are pass in chemistry')
else:
    print('supplyment in chemistry')
if sub5_marks >= 33:
    print('You are pass in maths')
else:
    print('supplyment in maths')
obtail_marks = sub1_marks + sub2_marks + sub3_marks + sub4_marks + sub5_marks
print('Total marks obtained:', obtail_marks)
total_marks = 500
percentage = (obtail_marks / total_marks) * 100
print('Total marks of all subjects:', total_marks)
print('Percentage:', percentage, '%')
# Out:
# English
# Hindi
# Physics
# Chemistry
# Maths
# You obtained 13 marks in English
# You obtained 23 marks in Hindi
# You obtained 80 marks in Physics
# You obtained 80 marks in Chemistry
# You obtained 80 marks in Maths
# You are fail
# supplyment in english
# supplyment in hindi
# You are pass in physics
# You are pass in chemistry
# You are pass in maths
# Total marks obtained: 276
# Total marks of all subjects: 500
# Percentage: 55.2 %
