# %%
course = input ('Enter your course').lower()
if ('dsa'== course) or ('c/c++'== course) or ('pyml'== course) or ('java'== course):

    days_attend = int(input('Enter no of days you have attend the class'))
    if( days_attend < 4 and days_attend > 0):
        print('You are allow for demo class')
    else:
        fee_status = input('Have you pay the fee y or n').upper()
        if fee_status == 'Y':
            print('You are allowed for class')
        else:
            print('Please pay the fee first')
else:
    print('choose the course we offered')
