# %%
Age =int(input('Enter your age'))
if (Age>=18):
    print('Allow for Voting')
else:
    print('Not Applicable')
# Out:
# Enter your age 18
# Allow for Voting

# %%
no = int(input('Enter any no'))
if (no%2==0):
    print ('User no is Even')
else:
    print('User no is Odd')
# Out:
# Enter any no 23
# User no is Odd

# %%
no =int(input('Enter no'))
if (no%7==0):
    print('Divisible')
else:
    print('Not divisible')
# Out:
# Enter no 21
# Divisible

# %%
no=int(input('Enter user no'))
if(no%5==0):
    print('HELLO')
else:
    print('BYY')
# Out:
# Enter user no 30
# HELLO

# %%
Unit=int(input('Enter user input'))
if (Unit<=100):
    amt=0
elif (Unit<=200):
        amt=(Unit-100)*5
else: 
        amt=500+(Unit-200)*10
print('Amount you have to pay :', amt)
# Out:
# Enter user input 90
# Amount you have to pay : 0

# %%
no=int(input('Enter no'))
print('last digit of no',no%10)
# Out:
# Enter no 8275
# last digit of no 5

# %%
no = int(input('Enter user no'))
dig=no%10
if (dig%3==0):
    print('YES')
else:
    print('NO')
# Out:
# Enter user no 98475
# NO

# %%
Marks=int(input('enter the marks'))
if(Marks>90):
    print('A Great')
elif(Marks>80)and(Marks<=90):
    print('B Great')
elif(Marks>=60)and(Marks<=80):
    print('c Great')
else:
    print('D Great')
# Out:
# enter the marks 91
# A Great

# %%
Price = int(input('Enter price of bike'))
if (Price>100000):
    tax=15/100*Price
elif(Price>50000)and(Price<=100000):
    tax=10/100*Price
else:
    tax=5/100*price
print('total tax',tax)
# Out:
# Enter price of bike 90587904
# total tax 13588185.6

# %%
Year = int(input('Enter year'))
if(Year%400==0):
    print('leap year')
elif(Year%4==0) and (Year%100!=0):
    print('leap year')
else:
    print('not leap year')
# Out:
# Enter year 1800
# not leap year

# %%
Day=int(input('Enter day no'))
if(Day==1):
    print('sun')
elif(Day==2):
    print('mon')
elif(Day==3):
    print('tue')
elif(Day==4):
    print('wed')
elif(Day==5):
    print('thu')
elif(Day==6):
    print('fri')
else:
    print('sat')
# Out:
# Enter day no 4
# wed

# %%
Month = int(input('Enter year month number'))
if(Month==1):
    print('jan')
elif(Month==2):
    print('fab')
elif(Month==3):
    print('mar')
elif(Month==4):
    print('arp')
elif(Month==5):
    print('may')
elif(Month==6):
    print('jun')
elif(Month==7):
    print('jul')
elif(Month==8):
    print('aug')
elif(Month==9):
    print('sep')
elif(Month==10):
    print('oct')
elif(Month==11):
    print('nov')
elif(Month==12):
    print('dec')
else:
    print('type no 1 to 12')
# Out:
# Enter year month number 4
# arp

# %%
num=input('Enter true or false')
if(True):
    print('101')
else:
    print('202')
# Out:
# Enter true or false 0
# 101

# %%
city=input('Red fort, Taj mahal, jal mahal').lower()
if(city=='red fort'):
    print('Delhi')
elif(city=='taj mahal'):
    print('Agar')
else:
    print('jaipur')
# Out:
# Red fort, Taj mahal, jal mahal red fort
# Delhi

# %%
a=int(input('Enter no'))
if(a>5 and a<=10):
    print('HELLO')
else:
    print('BEY')
# Out:
# Enter no 9
# HELLO

# %%
num=(input('Enter no'))
l=len(num)
if(l!=3):
    print('Enter three digit no')
else:
    print('Middle digit is',(int(num)%100//10))
# Out:
# Enter no 222
# Middle digit is 2

# %%
age=int(input('Enter age'))
if(age>=60):
    print('senior citizen')
else:
    print('junior citizen')
# Out:
# Enter age 60
# senior citizen

# %%
num1=int(input('Enter no'))
num2=int(input('Enter no'))
if(num1>num2):
    print('small no',num2)
else:
    print('small no',num1)
# Out:
# Enter no 2345
# Enter no 5432
# small no 2345

# %%
num=int(input("Enter no"))
if(num>0):
    print('Positive no')
else:
    print('Negative no')
# Out:
# Enter no -1
# Negative no

# %%
num=int(input('Enter no'))
if (num%2==0)and(num%3==0):
    print('Divisible no by 2 and 3')
else:
    print('Not Divisible by 2 and 3')
# Out:
# Enter no 6
# Divisible no

# %%
num1=int(input('Enter no 1'))
num2=int(input('Enter no 2'))
num3=int(input('Enter no3'))
if(num1>num2) and (num1>num3):
    print('lagest',num1)
elif(num2>num1)and(num2>num3):
    print('lagest',num2)
elif(num3>num1)and(num3>num2):
    print('lagest',num3)
# Out:
# Enter no 1 90
# Enter no 2 32
# Enter no3 59
# lagest 90

# %%
water=int(input('Enter celsius'))
if(water>100):
    print("Boiling water")
else:
    print('not boil')

# %%
people1=int(input("Enter age 1 People"))
people2=int(input("Enter age 2 People"))
people3=int(input("Enter age 3 People"))
people4=int(input("Enter age 4 People"))
if(people1<people2)and(people1<people3)and(people1<people4):
    print('Youngster',people1)
elif(people2<people1)and(people2<people3)and(people2<people4):
    print('Youngster',people2)
elif(people3<people2)and(people3<people1)and(people3<people4):
    print('Youngster',people3)
elif(people4<people2)and(people4<people1)and(people4<people3):
    print('Youngster',people4)
# Out:
# Enter age 1 People 40
# Enter age 2 People 21
# Enter age 3 People 13
# Enter age 4 People 67
# Youngster 13

# %%
people1=int(input("Enter age 1 People"))
people2=int(input("Enter age 2 People"))
people3=int(input("Enter age 3 People"))
people4=int(input("Enter age 4 People"))
if(people1>people2)and(people1>people3)and(people1>people4):
    print('oldest',people1)
elif(people2>people1)and(people2>people3)and(people2>people4):
    print('oldest',people2)
elif(people3>people2)and(people3>people1)and(people3>people4):
    print('oldest',people3)
elif(people4>people2)and(people4>people1)and(people4>people3):
    print('oldest',people4)
# Out:
# Enter age 1 People 20
# Enter age 2 People 12
# Enter age 3 People 10
# Enter age 4 People 22
# oldest 22

# %%
num=int(input('Enter the no'))
if(num%2==0):
    print('prime number')
else:
    print('not prime number')
# Out:
# Enter the no -2
# prime number

# %%
char=input('Enter char')
vow="aeiouAEIOU"
if char in vow:
    print('char is vovel')
else:
    print('not vovel')
# Out:
# Enter char a
# char is vovel

# %%
workday=int(input('enter work days'))
absentday=int(input('enter absent day'))
per=(workday-absentday)/workday*100
print('Your attandence',per)
if(per<75):
    print('not allow for exam')
else:
    print('allow for exam')
# Out:
# enter work days 30
# enter absent day 17
# Your attandence 43.333333333333336
# not allow for exam

# %%
num=int(input('Enter per'))
if(num>80):
    print('A+ great')
elif(num>60)and(num<=80):
    print('A great')
elif(num>50)and(num<=60):
    print('B+ great')
elif(num>45)and(num<=50):
    print('B great')
elif(num>25)and(num<=45):
    print('C great')
elif(num<25):
    print('D great')
# Out:
# Enter per 81
# A+ great

# %%
year=int(input('Enter years'))
sal=int(input('Enter salary'))
if(year>10):
    bouns=sal*10/100
elif(year>=6)and(year<=10):
    bouns=sal*8/100
elif(year<6):
    bouns=sal*5/100
print('total salary',bouns)
# Out:
# Enter years 4
# Enter salary 100
# total salary 5.0

# %%
amount=int(input("Enter amount"))
if(amount>10000):
    dis=amount*20/100
elif(amount>7000)and(amount<=10000):
    dis=amount*15/100
elif(amount<=7000):
    dis=amount*10/100
net=amount-dis
print('Price',net)
# Out:
# Enter amount 10000
# Price 8500.0
